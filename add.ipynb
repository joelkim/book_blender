# %% [markdown]
# # 객체 추가

# %% [markdown]
# ![그림: 객체 추가 메뉴](attachment:image.png)

# %% [markdown]
# ## 기본 생성 위치 및 크기

# %% [markdown]
# - 현재 3D Cursor 위치에 오브젝트 오리진이 오도록 생성됨
# - Scene unit 기준으로 크기가 정해짐

# %% [markdown]
# ## 이름
