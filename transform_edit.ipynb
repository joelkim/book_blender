# %% [markdown]
# # 에디트 모드 변형

# %% [markdown]
# - 에디트 모드에서는 vertex, edge, face 단위로 변형 가능

# %% [markdown]
# ## Joining and Separating

# %% [markdown]
# ## Subdivide

# %% [markdown]
# ## Inset Face

# %% [markdown]
# ## Parenting

# %% [markdown]
# ## Extrude
