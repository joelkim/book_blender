# %% [markdown]
# # 점/선/면 신규 생성

# %% [markdown]
# ## 애드온 설치

# %% [markdown]
# - 여기에서 설명하는 방법을 사용하려면 "Extra Mash Objects" 애드온을 설치해야 함

# %% [markdown]
# - 설치방법
#   - Edit > Preferences > Get Extensions
#   - "Extra Mash Objects" 입력
#   - 해당 애드온 선택 후 Install 버튼 클릭

# %% [markdown]
# ## 신규 점 생성

# %% [markdown]
# ![image.png](attachment:image.png)
