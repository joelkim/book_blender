# %% [markdown]
# # 3D 뷰포트

# %% [markdown]
# - 가장 많이 사용하는 기본 에디터

# %% [markdown]
# ![그림: 3D 뷰포트 에디터](attachment:image.png)

# %% [markdown]
# - 구성 요소
#   - 에디터 셀렉터
#   - 모드 셀렉터
#   - 메뉴
#   - ?
#   - 셀렉터빌리티/비저빌리티 툴
#   - 기즈모 툴
#   - 오버레이즈 툴
#   - 렌더 툴
#   - 툴바
#   - 기즈모
#   - 사이드바

# %% [markdown]
# ## 모드 셀렉터

# %% [markdown]
# - 3D 뷰포트는 6개의 모드 제공
#   - Object Mode
#   - Editor Mode
#   - Sculpt Mode
#   - Vertex Paint
#   - Weight Paint
#   - Texture Paint

# %% [markdown]
# ![그림: 3D 뷰포트 모드](attachment:image.png)

# %% [markdown]
# - 모드가 바뀌면 메뉴, 툴바 등을 포함한 다른 구성요소들도 바뀜
# - 가장 기본 모드는 오브젝트 모드와 에디터 모드

# %% [markdown]
# - 오브젝트 모드와 에디트 모드 비교
#   - 오브젝트 모드: 오브젝트 하나를 편집 가능 (이동, 확대 등)
#   - 에디트 모드: 오브젝트를 구성하는 점, 선, 면을 개별적으로 편집 가능 (모양의 변형)

# %% [markdown]
# ## 메뉴

# %% [markdown]
# - 모드에 따라 메뉴가 바뀜

# %% [markdown]
# ### 오브젝트 모드 메뉴

# %% [markdown]
# - 뷰(View)
# - 셀렉트(Select)
# - 애드(Add)
# - 오브젝트(Object)

# %% [markdown]
# ### 에디트 모드 메뉴

# %% [markdown]
# - 뷰(View)
# - 셀렉트(Select)
# - 애드(Add)
# - 메쉬(Mesh)
# - 버텍스(Vertex)
# - 엣지(Edge)
# - 페이스(Face)
# - UV

# %% [markdown]
# ## 셀렉터빌리티/비저빌리티 툴

# %% [markdown]
# ![그림: 셀렉터빌리티/비저빌리티 툴](attachment:image.png)

# %% [markdown]
# ## 기즈모 툴

# %% [markdown]
# ![그림: 기즈모 툴](attachment:image.png)

# %% [markdown]
# # 오버레이즈 툴

# %% [markdown]
# ![그림: 오버레이즈 툴](attachment:image.png)

# %% [markdown]
# ## 렌더 툴

# %% [markdown]
# ![그림: 렌더 아이콘](attachment:image.png)

# %% [markdown]
# - 와이어프레임(Wireframe): 뼈대만
# - 솔리드(Solid): 기본
# - 머터리얼 프리뷰(Material Preview): 재질
# - 렌더드(Rendered): 조명까지

# %% [markdown]
# ## 툴바

# %% [markdown]
# - 작업도구
# - 단축키: t
# - 모드에 따라 달라짐

# %% [markdown]
# ![그림: 오브젝트 모드 툴바](attachment:image.png)

# %% [markdown]
# ## 기즈모

# %% [markdown]
# ## 사이드바

# %% [markdown]
# - 단축키: n
# - 탭
#   - 아이템: 선택된 아이템의 위치 등
#   - 툴
#   - 뷰

# %% [markdown]
# ![그림: 사이드바(아이템)](attachment:image.png)

# %% [markdown]
# ## Last Operator panel

# %% [markdown]
# - 생성/변환 연산을 하면 왼쪽 아래에 생기는 패널
# - 생성/변환 연산을 하지 않으면 보이지 않는다.
